# %% [markdown]
# # Resúmen Data Science

# %% [markdown]
# ## Importo Librería Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Series (Listas Mejoradas)

# %%
# Creo la Lista
lista=['Argentina', 'Brasil', 'Bolivia', 'Chile', 'Paraguay', 'Uruguay']

# %%
# Creo la Serie a partir de la Lista
serie = pd.Series(lista)

# %%
# Imprimo la Serie
serie
# Out:
# 0    Argentina
# 1       Brasil
# 2      Bolivia
# 3        Chile
# 4     Paraguay
# 5      Uruguay
# dtype: object

# %%
# Muestro solo los valores de la Serie
serie.values
# Out:
# array(['Argentina', 'Brasil', 'Bolivia', 'Chile', 'Paraguay', 'Uruguay'],
#       dtype=object)

# %%
# Muestro los índices de la Serie
serie.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %% [markdown]
# ## DataFrame (Tablas Mejoradas)

# %%
# Creo 2 Listas
lista1 = [20, 21, 35, 45]
lista2 = ['Rodrigo', 'Maximiliano', 'Raul', 'Italo']

# %%
# Genero la Estructura de la Tabla
estruc_tabla = {'edad' : lista1, 'nombre' : lista2}

# %%
# Genero el DataFrame desde la Estructura
dataframe = pd.DataFrame(estruc_tabla)

# %%
# Muestro el DataFrame
dataframe
# Out:
#    edad       nombre
# 0    20      Rodrigo
# 1    21  Maximiliano
# 2    35         Raul
# 3    45        Italo

# %%
dataframe.describe()
# Out:
#             edad
# count   4.000000
# mean   30.250000
# std    11.982626
# min    20.000000
# 25%    20.750000
# 50%    28.000000
# 75%    37.500000
# max    45.000000

# %%
# extraer 1ra columna

# 1ra opcion
# dataframe.edad

#2da opcion (recomendada si el nombre de la columna tiene espacios ' ')
dataframe['edad']
# Out:
# 0    20
# 1    21
# 2    35
# 3    45
# Name: edad, dtype: int64

# %%
# Métodos de un DataFrame
# min   -   max -   median  -   std -   mode    -   sum -   count   -   unique  -   nunique -   mean

# Mínimo
print( dataframe['edad'].min() )

# Máximo
print( dataframe['edad'].max() )

# Desviación Estandar
print( dataframe['edad'].std() )

print( dataframe['edad'].mode() )

# Suma de todos los Valores
print( dataframe['edad'].sum() )

# Cantidad de Valores
print( dataframe['edad'].count() )

# Mediana
print( dataframe['edad'].median() )

# Lista de Valores Únicos
print( dataframe['edad'].unique() )

# Cantidad de Valores Únicos
print( dataframe['edad'].nunique() )

# Promedio
print( dataframe['edad'].mean() )
# Out:
# 20
# 45
# 11.98262631201246
# 0    20
# 1    21
# 2    35
# 3    45
# Name: edad, dtype: int64
# 121
# 4
# 28.0
# [20 21 35 45]
# 4
# 30.25

# %%
# Obtener 3er dato
dataframe.loc[2]
# Out:
# edad        35
# nombre    Raul
# Name: 2, dtype: object

# %%
# Obtener 2do y 3er dato
dataframe.loc[1:2]
# Out:
#    edad       nombre
# 1    21  Maximiliano
# 2    35         Raul

# %%
# Obtener 1er y 3er dato (paso como parámetro una lista de los valores que quiero ver)
dataframe.loc[[0,2]]
# Out:
#    edad   nombre
# 0    20  Rodrigo
# 2    35     Raul

# %%
# Método iloc no importa como se llamen los indices los toma como valores numericos 0 --> n-1
dataframe.iloc[1:4]
# Out:
#    edad       nombre
# 1    21  Maximiliano
# 2    35         Raul
# 3    45        Italo

# %%
# Agrego una nueva columna
dataframe['edad_al_cuadrado'] = dataframe['edad'] ** 2
dataframe
# Out:
#    edad       nombre  edad_al_cuadrado
# 0    20      Rodrigo               400
# 1    21  Maximiliano               441
# 2    35         Raul              1225
# 3    45        Italo              2025

# %%
# Muestro solamente las columnas de edades (paso como parámetros una lista con las columnas que quiero ver)
dataframe[['edad', 'edad_al_cuadrado']]
# Out:
#    edad  edad_al_cuadrado
# 0    20               400
# 1    21               441
# 2    35              1225
# 3    45              2025

# %%
# Muestro las primeras 'n' filas
dataframe.head(2)
# Out:
#    edad       nombre  edad_al_cuadrado
# 0    20      Rodrigo               400
# 1    21  Maximiliano               441

# %%
# Muestro las últimas 'n' filas
dataframe.tail(2)
# Out:
#    edad nombre  edad_al_cuadrado
# 2    35   Raul              1225
# 3    45  Italo              2025

# %%
# Muestra aleatoria de 'n' filas
dataframe.sample(2)
# Out:
#    edad       nombre  edad_al_cuadrado
# 1    21  Maximiliano               441
# 3    45        Italo              2025

# %%
# Filtrar por condicion
# dataframe [   condicion   ]
dataframe[  dataframe['edad'] > 30  ]
# Out:
#    edad nombre  edad_al_cuadrado
# 2    35   Raul              1225
# 3    45  Italo              2025

# %%
# Filtrar por condicion
# dataframe [   cond1  &   cond2   ]
dataframe[  (dataframe['edad'] < 25) | (dataframe['nombre'] == 'Italo') ]
# Out:
#    edad       nombre  edad_al_cuadrado
# 0    20      Rodrigo               400
# 1    21  Maximiliano               441
# 3    45        Italo              2025

# %%
# Eliminar Filas o Columnas
# axis 0 --> Filas
# axis 1 --> Columnas
dataframe = dataframe.drop('edad_al_cuadrado', axis=1)
dataframe
# Out:
#    edad       nombre
# 0    20      Rodrigo
# 1    21  Maximiliano
# 2    35         Raul
# 3    45        Italo

# %% [markdown]
# ## Matplotlib

# %%
# Importo las librerías
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
a = [1, 2]
b = [3, 4]

# %%
# Método de codificación como Objetos

    # Defino el Lienzo
fig, ax = plt.subplots()

    # Configuración del Gráfico
        # Etiquetar ejes
ax.set_xlabel('Nro de Clientes')
ax.set_ylabel('Tiempo de Espera')
        
        # Añadir título
ax.set_title('Mi primer gráfico')
        
        # Definir Límites
            # ax.set_xlim
            # ax.set_ylim
        
        # Líneas [h]orizontales y [v]erticales
            # ax.axhline
            # ax.axvline
    
    # Ejecución de la/s Gráfica/s
ax.plot(a,b)

        # Añadir leyenda
ax.legend(['tendencia'])

# %% [markdown]
# Ejemplo

# %%
df_lluvias = pd.read_csv('pune_1965_to_2002.csv')

# %%
df_lluvias
# Out:
#     Year    Jan    Feb    Mar     Apr     May      Jun      Jul      Aug  \
# 0   1965  0.029  0.069  0.000  21.667  17.859  102.111  606.071  402.521
# 1   1966  0.905  0.000  0.000   2.981  63.008   94.088  481.942   59.386
# 2   1967  0.248  3.390  1.320  13.482  11.116  251.314  780.006  181.069
# 3   1968  0.318  3.035  1.704  23.307   7.441  179.872  379.354  171.979
# 4   1969  0.248  2.524  0.334   4.569   6.213  393.682  678.354  397.335
# 5   1970  0.070  0.000  0.001  16.218  68.036  300.546  330.502  283.476
# 6   1971  0.000  0.000  0.000   0.812  57.691  297.187  122.195  372.693
# 7   1972  0.000  0.029  0.000   5.982  19.101  132.413  338.484   68.741
# 8   1973  0.000  2.969  0.234   3.925  14.978  304.484  696.024  256.932
# 9   1974  0.000  0.000  6.427  16.864  51.209  148.697  405.359  319.651
# 10  1975  0.333  0.585  0.000   0.061  30.651  359.369  474.143  404.372
# 11  1976  0.000  0.000  5.993   4.454   3.577  773.737  545.379  436.912
# ...

# %%
# Reemplazo los índices de la tabla por los 'Años' que estan en la 1er columna
df_lluvias.index = df_lluvias['Year']
# Elimino la 1er columna ya que ahora son los índices
df_lluvias = df_lluvias.drop('Year', axis='columns')

# %%
df_lluvias.sample(3)
# Out:
#         Jan    Feb    Mar     Apr     May      Jun      Jul      Aug      Sep  \
# Year
# 1972  0.000  0.029  0.000   5.982  19.101  132.413  338.484   68.741  120.415
# 1965  0.029  0.069  0.000  21.667  17.859  102.111  606.071  402.521   69.511
# 1994  0.879  0.325  2.415  16.823  33.378  749.030  707.986  230.898  115.509
#
#           Oct     Nov     Dec
# Year
# 1972    1.078  24.089   0.143
# 1965    5.249  16.232  22.075
# 1994  116.348  14.098   0.000

# %%
# Ver información del DataSets
df_lluvias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 1965 to 2002
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     38 non-null     float64
#  1   Feb     38 non-null     float64
#  2   Mar     38 non-null     float64
#  3   Apr     38 non-null     float64
#  4   May     38 non-null     float64
#  5   Jun     38 non-null     float64
#  6   Jul     38 non-null     float64
#  7   Aug     38 non-null     float64
#  8   Sep     38 non-null     float64
#  9   Oct     38 non-null     float64
#  10  Nov     38 non-null     float64
#  11  Dec     38 non-null     float64
# dtypes: float64(12)
# memory usage: 3.9 KB

# %%
# Armo los ejes
x = df_lluvias.index
y = df_lluvias.sum(axis='columns')

# %%
# Método de codificación como Objetos

    # Defino el Lienzo
fig, ax = plt.subplots(figsize = (12, 4))   # figsize --> tamaño gráfico (ancho, alto)

    # Configuración del Gráfico
        # Etiquetar ejes
ax.set_xlabel('Años')
ax.set_ylabel('Precipitación acumulada en mm.')
        
        # Añadir título
ax.set_title('Precipitaciones acumuladas segun el año')
        
        # Definir Límites
ax.set_xlim(df_lluvias.index[0], df_lluvias.index[-1])
            # ax.set_ylim
        
        # Líneas [h]orizontales y [v]erticales
            # ax.axhline
            # ax.axvline
    
    # Ejecución de la/s Gráfica/s
        # ax.plot --> gráfico de líneas
        # ax.scatter --> gráfico de puntos
        # ax.bar --> gráfico de barras
ax.plot(x, y, label = 'Precipitaciones acumuladas')

        # Añadir leyenda
ax.legend(loc = 'best')    # localización --> best, right, etc.

# %%
# Exportar la imagen, formatos soportados: jpeg, jpg, png, pdf, svg
fig.savefig('precipitaciones_anio.pdf')
fig.savefig('precipitaciones_anio.jpg')

# %%
# Trabajando con Datos Ausentes
# Numpy --> np.nan
    # Marcarlos
    # df_lluvias.isnull()
    
    # Reemplazarlos por el valor que le pasemos
    # df_lluvias.fillna(0)
        # ej. reemplazamos por media de los valores de la columna
        # media = df_lluvias['Apr'].mean()
        # df_lluvias['Apr'] = df_lluvias['Apr'].fillna(media)
    
    # Eliminarlos
    # df_lluvias.dropna()

# %%
# Ver cuántos nulos tiene cada columna
    # df_lluvias.isnull().sum()

# %%
# Ver 'cambios porcentuales' respecto al 1er valor de la columna
    # df_lluvias.pct_change()

# %%
# Cuenta las categorias de las columnas
    # df_lluvias['columna'].value_counts()

# %% [markdown]
# # Agregaciones - Agrupamientos

# %%
df_pokemon = pd.read_csv('pokemon_data.txt', sep='\t')
df_pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# Hace descripciones por cada columna
df_pokemon.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# Cuento cuántos tipos de pokemones del Tipo 1 hay
df_pokemon['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
# Cuento cuántos tipos de pokemones del Tipo 1 hay (en porcentaje)
df_pokemon['Type 1'].value_counts(normalize=True)
# Out:
# Water       0.14000
# Normal      0.12250
# Grass       0.08750
# Bug         0.08625
# Psychic     0.07125
# Fire        0.06500
# Electric    0.05500
# Rock        0.05500
# Dragon      0.04000
# Ground      0.04000
# Ghost       0.04000
# Dark        0.03875
# Poison      0.03500
# Steel       0.03375
# Fighting    0.03375
# Ice         0.03000
# Fairy       0.02125
# Flying      0.00500
# Name: Type 1, dtype: float64

# %%
# Cuántos valores únicos hay en esta categoria
df_pokemon['Type 1'].nunique()
# Out:
# 18

# %%
# Para describir por categoria
    # Promedios de 'Salud', 'Ataque' y 'Defensa' en los diferentes tipos de pokemones
df_pokemon.groupby(by='Type 1')['HP', 'Attack', 'Defense'].mean()
# Out:
# /tmp/ipykernel_23942/2667720518.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_pokemon.groupby(by='Type 1')['HP', 'Attack', 'Defense'].mean()
#                  HP      Attack     Defense
# Type 1
# Bug       56.884058   70.971014   70.724638
# Dark      66.806452   88.387097   70.225806
# Dragon    83.312500  112.125000   86.375000
# Electric  59.795455   69.090909   66.295455
# Fairy     74.117647   61.529412   65.705882
# Fighting  69.851852   96.777778   65.925926
# Fire      69.903846   84.769231   67.769231
# Flying    70.750000   78.750000   66.250000
# Ghost     64.437500   73.781250   81.187500
# Grass     67.271429   73.214286   70.800000
# Ground    73.781250   95.750000   84.843750
# Ice       72.000000   72.750000   71.416667
# Normal    77.275510   73.469388   59.846939
# Poison    67.250000   74.678571   68.821429
# Psychic   70.631579   71.456140   67.684211
# ...

# %%
# Para describir por categoria
    # Promedios de 'Salud', 'Ataque' y 'Defensa' en los diferentes tipos de pokemones
    # Ordeno los resultados de Mayor a Menor
df_pokemon.groupby(by='Type 1')['HP', 'Attack', 'Defense'].mean().sort_values(by='HP', ascending=False)
# Out:
# /tmp/ipykernel_23942/1250216177.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_pokemon.groupby(by='Type 1')['HP', 'Attack', 'Defense'].mean().sort_values(by='HP', ascending=False)
#                  HP      Attack     Defense
# Type 1
# Dragon    83.312500  112.125000   86.375000
# Normal    77.275510   73.469388   59.846939
# Fairy     74.117647   61.529412   65.705882
# Ground    73.781250   95.750000   84.843750
# Water     72.062500   74.151786   72.946429
# Ice       72.000000   72.750000   71.416667
# Flying    70.750000   78.750000   66.250000
# Psychic   70.631579   71.456140   67.684211
# Fire      69.903846   84.769231   67.769231
# Fighting  69.851852   96.777778   65.925926
# Grass     67.271429   73.214286   70.800000
# Poison    67.250000   74.678571   68.821429
# Dark      66.806452   88.387097   70.225806
# Rock      65.363636   92.863636  100.795455
# ...

# %%
# Hago 2 agrupamientos (Si son o no Legendarios y por Tipo)
df_pokemon.groupby(['Legendary', 'Type 1'])['HP', 'Attack', 'Defense'].mean()
# Out:
# /tmp/ipykernel_23942/1376150197.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_pokemon.groupby(['Legendary', 'Type 1'])['HP', 'Attack', 'Defense'].mean()
#                             HP      Attack     Defense
# Legendary Type 1
# False     Bug        56.884058   70.971014   70.724638
#           Dark       64.655172   86.862069   68.689655
#           Dragon     72.650000  103.400000   78.150000
#           Electric   57.325000   66.125000   65.425000
#           Fairy      70.875000   57.187500   63.875000
#           Fighting   69.851852   96.777778   65.925926
#           Fire       67.085106   82.191489   64.531915
#           Flying     62.500000   50.000000   57.500000
#           Ghost      58.733333   71.366667   79.266667
#           Grass      65.940299   72.119403   70.283582
#           Ground     70.821429   88.000000   79.821429
# ...

# %%
# Tipos de Datos en las columnas
df_pokemon.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
df_pokemon.describe(include=['object', 'bool'])
# Out:
#              Name Type 1  Type 2 Legendary
# count         800    800     414       800
# unique        800     18      18         2
# top     Bulbasaur  Water  Flying     False
# freq            1    112      97       735

# %%
# Criterio de Agregación
criterio_de_agregacion = {'HP':'mean', 'Attack':'mean', 'Speed':['max', 'mean', 'min']}

df_pokemon.groupby('Legendary').agg(criterio_de_agregacion)
# Out:
#                   HP      Attack Speed
#                 mean        mean   max        mean min
# Legendary
# False      67.182313   75.669388   160   65.455782   5
# True       92.738462  116.676923   180  100.184615  50
